# %%
from google.cloud import storage
import os

BUCKET_NAME = "sicoescan"
FOLDER_PREFIX = "forms/"  # The 'folder' inside the bucket (end with /)
OUTPUT_FILENAME = "todos.txt"
KEY_FILE_PATH = "firebase-credentials.json" # Only if not using env vars
